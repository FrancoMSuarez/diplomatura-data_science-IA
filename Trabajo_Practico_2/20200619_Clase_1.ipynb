# %% [markdown]
# ## EJERCICIOS EN CLASE 1, 2020-06-16
# **_Grupo 2-2_**

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
df = pd.read_csv("../wtageinf.csv")

# %%
df[:2]
# Out:
#    Sex  Agemos         L         M         S        P3        P5       P10  \
# 0    1     0.0  1.815151  3.530203  0.152385  2.355451  2.526904  2.773802
# 1    1     0.5  1.547523  4.003106  0.146025  2.799549  2.964656  3.209510
#
#         P25       P50       P75       P90       P95       P97
# 0  3.150611  3.530203  3.879077  4.172493  4.340293  4.446488
# 1  3.597396  4.003106  4.387423  4.718161  4.910130  5.032625

# %%
df_m=df[df.Sex==1]
df_f=df[df.Sex==2]
df_m.sample()
# Out:
#     Sex  Agemos         L          M         S        P3       P5       P10  \
# 19    1    18.5 -0.152762  11.804779  0.108317  9.658975  9.90183  10.28968
#
#           P25        P50        P75        P90        P95        P97
# 19  10.977527  11.804779  12.704728  13.582902  14.141875  14.519093

# %%
df_f.sample()
# Out:
#     Sex  Agemos         L          M        S       P3        P5       P10  \
# 55    2    16.5 -0.403689  10.672507  0.10515  8.82337  9.029399  9.360079
#
#          P25        P50        P75        P90        P95        P97
# 55  9.951715  10.672507  11.468779  12.258624  12.768249  13.115272

# %%
plt.figure(figsize=(20,5))
plt.xlim(0,35)
for column in df_m.loc[0, "P3":"P97"].index:
    sb.lineplot(data=df_m, x="Agemos", y=column)

# %%
plt.figure(figsize=(20,5))
plt.xlim(0,35)
for column in df_m.loc[0, "P3":"P97"].index:
    sb.lineplot(data=df_f, x="Agemos", y=column)

# %%
df2 = pd.read_json("pasos.json")
df2.sample()
# Out:
#     province                    location          name
# 125  Cordoba  [-31.3154367, -64.2145085]  AERO CORDOBA

# %%
# Nombre de provincias en lower case
df2["province"] = df2["province"].str.capitalize()
df2
# Out:
#              province                    location  \
# 0    Tierra del fuego   [-54.832543, -68.3712885]
# 1    Tierra del fuego  [-54.8249379, -68.3258626]
# 2    Tierra del fuego  [-54.8096728, -68.3114748]
# 3    Tierra del fuego  [-54.8019121, -68.3029511]
# 4          Santa cruz  [-51.6896359, -72.2993574]
# ..                ...                         ...
# 247            Chubut  [-45.2213569, -71.3610803]
# 248        Santa cruz  [-48.8772007, -72.7288579]
# 249      Buenos aires  [-34.1176359, -57.9897668]
# 250      Buenos aires  [-34.1176359, -57.9897668]
# 251          Misiones  [-25.6221088, -54.6080637]
#
#                                 name
# 0         SAN SEBASTIAN  ( USHUAIA )
# 1            AERO PUBLICO DE USHUAIA
# 2        PUERTO USHUAIA (PREFECTURA)
# 3                     PUERTO USHUAIA
# 4          PASO LAURITA CASAS VIEJAS
# ..                               ...
# 247                  PASO PAMPA ALTA
# 248  PASO PORTEZUELO DE LA DIVISORIA
# 249                      ROU COLONIA
# 250                      ROU COLONIA
# 251    ZONA FRANCA IGUAZU (TRANSITO)
#
# [252 rows x 3 columns]

# %%
df2[df2["province"].str.contains("Aeropuerto")] = 'Santa Cruz'

# %%
df3=df2.groupby("province").count().reset_index()
df3
# Out:
#                province  location  name
# 0          Buenos aires        48    48
# 1             Catamarca         3     3
# 2                 Chaco         3     3
# 3                Chubut        15    15
# 4               Cordoba         3     3
# 5            Corrientes        15    15
# 6               Córdoba         1     1
# 7            Entre rios        13    13
# 8               Formosa        11    11
# 9                 Jujuy         8     8
# 10             La rioja         3     3
# 11              Mendoza        14    14
# 12             Misiones        38    38
# 13              Neuquen        11    11
# 14            Rio negro         8     8
# 15                Salta         4     4
# 16             San juan         5     5
# 17             San luis         2     2
# 18           Santa Cruz         1     1
# 19           Santa cruz        20    20
# 20             Santa fe        11    11
# 21  Santiago del estero         4     4
# 22     Tierra del fuego         9     9
# 23              Tucuman         2     2

# %%
plt.figure(figsize=(20, 5))
sb.barplot(data=df3, x="province", y="location")
plt.xticks(rotation=90);
